# %%
import numpy as np
import matplotlib.pyplot as plt
class DataPlot:
    def Plot1():
        x=np.array([10,20,30,40,50,60])
        y=np.array([65,55,45,35,25,15])
        plt.plot(x,marker="o",mfc="red",mec="blue",ms=8,color="purple",linewidth="4")
        plt.show()
DataPlot.Plot1()
